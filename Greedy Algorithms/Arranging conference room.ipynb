# %% [markdown]
# * 최단시간 순서대로 정렬 후, 넣을 수 있는지 비교해서 넣기.
# * 매 회의 삽입마다 해당 회의를 제외하고 알고리즘을 돌렸을때 더 큰 숫자가 나올경우 제거.

# %%
def sort(lst):
    lst_dic = {}
    for i in range(len(lst)):
        lst_time = list(map(int, lst[i].split()))
        lst_dic[i] = lst_time[1] - lst_time[0]
    #print(lst_dic)
    lst_dic_sort = sorted(lst_dic.items(), key=lambda x:x[1])
    #print('dic:',lst_dic_sort)
    lst_sort = []
    
    for j in range(len(lst_dic_sort)):
        lst_sort.append(lst[lst_dic_sort[j][0]])
        #print(lst_sort)

    sorted_lst = []
    for k in range(len(lst_sort)):
        sorted_lst.append(list(map(int, lst_sort[k].split())))

    return sorted_lst
'''
a = ['1 3','4 6', '5 6']
print(sort(a))
print(sort(a)[0][0])
'''
# Out:
# "\na = ['1 3','4 6', '5 6']\nprint(sort(a))\nprint(sort(a)[0][0])\n"

# %%
def check_redundancy(lst,schdl):
    for i in range(len(schdl)):
            if schdl[i][0]<lst[0][0]<schdl[i][1] or schdl[i][0]<lst[0][1]<schdl[i][1]:
                return False
    return True

def arg_conf(lst, schdl):
    for i in range(len(lst)):
        print(lst)
        if check_redundancy(lst[i],schdl):
            print(lst[i][0], lst[i][1])
            schdl.append([lst[i][0], lst[i][1]]) # 1차원 리스트가 들어올때 문제 발생
    return len(schdl)

# %%
number = int(input())
conf = []
for i in range(number):
    conf.append(input())
sorted_conf = sort(conf)

selected_conf = []

for j in range(len(sorted_conf)):
    if arg_conf(sorted_conf[j], selected_conf) >= arg_conf(sorted_conf[j+1], selected_conf):
        selected_conf.append(sorted_conf[j])
        
print(len(selected_conf.append))
# Out:
# 2
# 1 5
# 2 4
# [2, 4]
# 2 4
# [2, 4]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-1214ac925144> in <module>
#       8
#       9 for j in range(len(sorted_conf)):
# ---> 10     if arg_conf(sorted_conf[j], selected_conf) >= arg_conf(sorted_conf[j+1], selected_conf):
#      11         selected_conf.append(sorted_conf[j])
#      12
#
# <ipython-input-47-8ef679520455> in arg_conf(lst, schdl)
#       8     for i in range(len(lst)):
#       9         print(lst)
# ---> 10         if check_redundancy(lst[i],schdl):
#      11             print(lst[0], lst[1])
#      12             schdl.append([lst[0], lst[1]])
#
# <ipython-input-47-8ef679520455> in check_redundancy(lst, schdl)
#       1 def check_redundancy(lst,schdl):
#       2     for i in range(len(schdl)):
# ----> 3             if schdl[i][0]<lst[0][0]<schdl[i][1] or schdl[i][0]<lst[0][1]<schdl[i][1]:
#       4                 return False
#       5     return True
#
# TypeError: 'int' object is not subscriptable
